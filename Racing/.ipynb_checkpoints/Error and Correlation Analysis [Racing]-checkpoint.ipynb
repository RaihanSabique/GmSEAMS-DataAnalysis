# %%
import pandas as pd
import numpy as np
import seaborn as sns # For pairplots and heatmaps
import matplotlib.pyplot as plt
import glob

# %% [markdown]
# ### Data Extraction

# %%
data_path = "/Users/mdraihanmia/Ubicomp/PMNL/MotEv/MotorEvaluation/analysis/ExperimentalAnalysis/data/game/FeasibilityData/"
merged_df = []
for file_name in glob.glob(data_path+'*.csv'):
    print(file_name)
    df = pd.read_csv(file_name)
    merged_df.append(df)
    # print(df.columns)
    # df = pd.concat([df, pd.read_csv(file_name)],axis=0, ignore_index=True, sort=False)
df_racing = pd.concat(merged_df)
# Out:
# /Users/mdraihanmia/Ubicomp/PMNL/MotEv/MotorEvaluation/analysis/ExperimentalAnalysis/data/game/FeasibilityData/Molly_Millard.csv
# /Users/mdraihanmia/Ubicomp/PMNL/MotEv/MotorEvaluation/analysis/ExperimentalAnalysis/data/game/FeasibilityData/at_the_market_error.csv
# /Users/mdraihanmia/Ubicomp/PMNL/MotEv/MotorEvaluation/analysis/ExperimentalAnalysis/data/game/FeasibilityData/Lucille.csv
# /Users/mdraihanmia/Ubicomp/PMNL/MotEv/MotorEvaluation/analysis/ExperimentalAnalysis/data/game/FeasibilityData/Discovery_2.csv
# /Users/mdraihanmia/Ubicomp/PMNL/MotEv/MotorEvaluation/analysis/ExperimentalAnalysis/data/game/FeasibilityData/Discovery_1.csv
# /Users/mdraihanmia/Ubicomp/PMNL/MotEv/MotorEvaluation/analysis/ExperimentalAnalysis/data/game/FeasibilityData/Theo.csv

# %%
from datetime import date
from datetime import datetime
def time_diff(x, y):
#     print(x,y)
#     x = "1900-01-01 " + x
#     y = "1900-01-01 " + y 
    a = datetime.strptime(x, '%Y-%m-%d %H:%M:%S.%f')
    b = datetime.strptime(y, '%Y-%m-%d %H:%M:%S.%f')
#     a = a.split(":")
#     a = float(a[-1])
#     b = b.split(":")
#     a = float(a[-1])
#     print(a,b)
#     z = b.microseconds - a.microseconds
    return (b - a).total_seconds() # in seconds
def calculate_age(born):
    if(not isinstance(born, str)):
        return int(born)
    born = datetime.strptime(born, '%Y-%m-%d')
    today = date.today()
    return today.year - born.year - ((today.month, today.day) < (born.month, born.day))

# %%
df_racing.columns
# Out:
# Index(['user_id', 'name', 'age', 'location', 'used_hand', 'study_id',
#        'study_day', 'try_allowed', 'try_number', 'try_remaining',
#        'study_start', 'study_end', 'game_type', 'star_time', 'end_time',
#        'total_time', 'data', 'hand', 'object_name', 'drop_box', 'p1', 'p2',
#        'is_error', 'rmse', 'time_diff_ss'],
#       dtype='object')

# %%
df_racing = df_racing[df_racing['game_type'] == "tracking_test"]
df_racing["age"] = df_racing.apply(lambda x: calculate_age(x.age), axis=1)
df_racing = df_racing[(df_racing['age'] < 14.0) & (df_racing['age'] >=4.0)]

# %%
import re
import datefinder
pattern = "':"
time_pattern = '%Y-%m-%d %H:%M:%S.%f'
def get_movement(data, name):
    data = data.replace("{", "(")
    data = data.replace("}", ")")
    data = data.replace("[, ", "[")
    data = "{" + data[1:-1] + "}"
    # print(datetime.strptime(data, pattern).date())
    # matches = datefinder.find_dates(data)            
    # for match in matches:
    #     print("match found ",match)
    # print(eval(data))
    index = [match.start() for match in re.finditer(pattern, data)]
    
    path = eval(data[index[0]+len(pattern):index[1]-len(", 'timeline")])
    timeline = data[index[1]+len(pattern):index[2]-len(", 'try_info")]
    timeline = timeline.replace(', ', '", "')
    timeline = timeline.replace('[', '["')
    timeline = timeline.replace(']', '"]')
    timeline = eval(timeline)
    hand = data[index[2]+len(pattern):-1]
    return path, timeline, time_diff(timeline[0], timeline[-1]), hand

# %%
df_data[["path", "time", "time_diff", "hand"]]  = df_data.apply(lambda x: get_movement(x.data, x["name"]), axis=1, result_type="expand")

# %%
df_data[["path", "time", "time_diff", "hand"]]
# Out:
#                                                  path  \
# 2   [(102.99996948242188, 585), (102.5, 587), (102...
# 3   [(131, 579), (141.00003051757812, 579), (144, ...
# 4   [(115.5, 595), (127.5, 595), (132.5, 595), (14...
# 5   [(107.5, 591.5), (114.5, 589), (120, 588), (12...
# 6   [(126.5, 565.5), (128.99996948242188, 565), (1...
# ..                                                ...
# 8   [(940, 230.99998474121094), (944.5, 235.499984...
# 9   [(114, 571.5), (123.50003051757812, 574), (124...
# 10  [(81.5, 588.5), (84, 588.5), (96, 588.5), (111...
# 11  [(599, 387), (592.5, 387), (591, 387.5), (589....
# 12  [(613, 362.5), (606, 362.5), (603.5, 357.00003...
#
#                                                  time  time_diff         hand
# 2   [2023-06-20 15:08:18.4450, 2023-06-20 15:08:18...     21.461    'Right#1'
# 3   [2023-06-20 15:08:46.4710, 2023-06-20 15:08:46...     12.828    'Right#2'
# 4   [2023-06-20 15:09:03.3650, 2023-06-20 15:09:03...      9.096    'Right#3'
# 5   [2023-06-20 15:09:16.1290, 2023-06-20 15:09:16...     11.861     'Left#4'
# 6   [2023-06-20 15:09:30.4580, 2023-06-20 15:09:30...     11.727     'Left#5'
# ..                                                ...        ...          ...
# 8   [2023-06-19 14:09:22.2710, 2023-06-19 14:09:22...     12.627    'Right#7'
# 9   [2023-06-19 14:09:38.5340, 2023-06-19 14:09:38...     11.259     'Left#8'
# 10  [2023-06-19 14:09:52.9270, 2023-06-19 14:09:52...     11.728    'Right#9'
# 11  [2023-06-19 14:10:07.5740, 2023-06-19 14:10:07...     10.977    'Left#10'
# 12  [2023-06-19 14:10:20.3370, 2023-06-19 14:10:20...     10.875   'Right#11'
#
# [77 rows x 4 columns]

# %% [markdown]
# #### Get Baseline Path Data

# %%
import pandas as pd
df = pd.read_csv("Experiment_.csv")
df_race = df.iloc[0]

# %%
def get_points(data):
    splited_data = data.split(",")
#     print(splited_data)
    x = []
    y = []
    x.append(float(splited_data[0][1:]))
    for i in range(1, len(splited_data)-1):
        p = splited_data[i].strip()
        p = p.split("}{")
        y.append(float(p[0]))
        x.append(float(p[1]))
    
    y.append(float(splited_data[-1][1:-2]))
#     print("X= ", x)
#     print("Y= ", y)
    return x, y

# %%
base_x, base_y = get_points(df_race["data"])

# %%
# importing the required libraries
import matplotlib.pyplot as plt
import numpy as np
# # define data values
plt.rcParams.update({'font.size': 16})
x = np.array(base_x)  # X-axis points
y = np.array(base_y)  # Y-axis points
plt.plot(x, y)  # Plot the chart
plt.show()  # display

# %% [markdown]
# #### Plot first 6 tries

# %%
df_race_test = df_data.iloc[:6]
df_race_test[["path", "time", "time_diff", "hand"]]
# Out:
#                                                 path  \
# 2  [(102.99996948242188, 585), (102.5, 587), (102...
# 3  [(131, 579), (141.00003051757812, 579), (144, ...
# 4  [(115.5, 595), (127.5, 595), (132.5, 595), (14...
# 5  [(107.5, 591.5), (114.5, 589), (120, 588), (12...
# 6  [(126.5, 565.5), (128.99996948242188, 565), (1...
# 7  [(157, 573), (160, 573), (160.50003051757812, ...
#
#                                                 time  time_diff        hand
# 2  [2023-06-20 15:08:18.4450, 2023-06-20 15:08:18...     21.461   'Right#1'
# 3  [2023-06-20 15:08:46.4710, 2023-06-20 15:08:46...     12.828   'Right#2'
# 4  [2023-06-20 15:09:03.3650, 2023-06-20 15:09:03...      9.096   'Right#3'
# 5  [2023-06-20 15:09:16.1290, 2023-06-20 15:09:16...     11.861    'Left#4'
# 6  [2023-06-20 15:09:30.4580, 2023-06-20 15:09:30...     11.727    'Left#5'
# 7  [2023-06-20 15:09:46.0190, 2023-06-20 15:09:46...     15.594    'Left#6'

# %%
plt.rcParams.update({'font.size': 12})
# plt.rcParams["legend.loc"] = 'right'
dt=np.dtype('float,float')

for i, row in df_race_test.iterrows():
    points = np.array(row["path"],dtype=dt)
    # x = np.array(row["path"][0])  # X-axis points
    # y = np.array(row["path"][1])  # Y-axis points
    plt.plot(points["f0"], points["f1"], label=row["hand"])  # Plot the chart
    j+=1
plt.xlabel('X')
plt.ylabel('Y')
# plt.title("Movement path of racing game")
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1));
plt.show()  # display
